# %% [markdown]
# <a href="https://colab.research.google.com/github/praiseandrews/Data-Science-Learning/blob/main/Assignment_Operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Membership Operators

fruits = ["apple", "banana", "mango"]

print("apple" in fruits)
print("grapes" in fruits)
print("grapes" not in fruits)
# Out:
# True
# False
# True
