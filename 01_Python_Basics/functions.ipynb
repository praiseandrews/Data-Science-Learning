# %% [markdown]
# <a href="https://colab.research.google.com/github/praiseandrews/Data-Science-Learning/blob/main/01_Python_Basics/functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Function Definition

def greet(name):
    print("Hello,", name)

greet("Praisy")

# Function with Return Value

def add(a, b):
    return a + b

result = add(10, 5)

print("Sum:", result)
# Out:
# Hello, Praisy
# Sum: 15
