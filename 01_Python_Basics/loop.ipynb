# %% [markdown]
# <a href="https://colab.research.google.com/github/praiseandrews/Data-Science-Learning/blob/main/01_Python_Basics/loop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# For Loop

print("Numbers from 1 to 5:")

for i in range(1, 6):
    print(i)

# While Loop

print("\nCountdown:")

count = 5

while count > 0:
    print(count)
    count -= 1

print("Done!")
# Out:
# Numbers from 1 to 5:
# 1
# 2
# 3
# 4
# 5
#
# Countdown:
# 5
# 4
# 3
# 2
# 1
# Done!
