# %% [markdown]
# <a href="https://colab.research.google.com/github/praiseandrews/Data-Science-Learning/blob/main/04_Data_Visualization/data_visualization_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Sample Dataset
data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Emma"],
    "Age": [23, 25, 22, 24, 26],
    "Salary": [40000, 50000, 45000, 48000, 55000]
}

df = pd.DataFrame(data)

# ==========================
# Bar Chart
# ==========================

plt.figure(figsize=(6,4))
plt.bar(df["Name"], df["Salary"])
plt.title("Salary by Employee")
plt.xlabel("Employee")
plt.ylabel("Salary")
plt.show()

# ==========================
# Line Chart
# ==========================

plt.figure(figsize=(6,4))
plt.plot(df["Name"], df["Salary"], marker="o")
plt.title("Salary Trend")
plt.xlabel("Employee")
plt.ylabel("Salary")
plt.show()

# ==========================
# Histogram
# ==========================

plt.figure(figsize=(6,4))
plt.hist(df["Age"], bins=5)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# ==========================
# Scatter Plot
# ==========================

plt.figure(figsize=(6,4))
plt.scatter(df["Age"], df["Salary"])
plt.title("Age vs Salary")
plt.xlabel("Age")
plt.ylabel("Salary")
plt.show()

# ==========================
# Seaborn Plot
# ==========================

sns.scatterplot(data=df, x="Age", y="Salary")
plt.title("Seaborn: Age vs Salary")
plt.show()
