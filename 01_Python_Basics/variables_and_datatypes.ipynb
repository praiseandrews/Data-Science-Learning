# %% [markdown]
# <a href="https://colab.research.google.com/github/praiseandrews/Data-Science-Learning/blob/main/01_Python_Basics/variables_and_datatypes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "Praisy"
age = 23
height = 5.4
is_student = True

print(name)
print(age)
print(height)
print(is_student)
# Out:
# Praisy
# 23
# 5.4
# True
