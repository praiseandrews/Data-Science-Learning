# %% [markdown]
# <a href="https://colab.research.google.com/github/praiseandrews/Data-Science-Learning/blob/main/03_Pandas_Practice/pandas_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

print("===== CREATING A DATAFRAME =====")

data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Emma"],
    "Age": [23, 25, 22, 24, 26],
    "Salary": [40000, 50000, 45000, 48000, 55000]
}

df = pd.DataFrame(data)

print(df)

print("\n===== DATA CLEANING =====")

# Introduce a missing value
df.loc[2, "Salary"] = None

print("Before Cleaning:")
print(df)

# Fill missing value with mean
df["Salary"] = df["Salary"].fillna(df["Salary"].mean())

print("\nAfter Cleaning:")
print(df)

print("\n===== FILTERING =====")

high_salary = df[df["Salary"] > 45000]

print(high_salary)

print("\n===== SORTING =====")

sorted_df = df.sort_values(by="Salary", ascending=False)

print(sorted_df)

print("\n===== GROUPING AND AGGREGATION =====")

df["Department"] = ["IT", "HR", "IT", "HR", "IT"]

grouped = df.groupby("Department")["Salary"].mean()

print(grouped)
# Out:
# ===== CREATING A DATAFRAME =====
#       Name  Age  Salary
# 0    Alice   23   40000
# 1      Bob   25   50000
# 2  Charlie   22   45000
# 3    David   24   48000
# 4     Emma   26   55000
#
# ===== DATA CLEANING =====
# Before Cleaning:
#       Name  Age   Salary
# 0    Alice   23  40000.0
# 1      Bob   25  50000.0
# 2  Charlie   22      NaN
# 3    David   24  48000.0
# 4     Emma   26  55000.0
#
# After Cleaning:
#       Name  Age   Salary
# 0    Alice   23  40000.0
# 1      Bob   25  50000.0
# 2  Charlie   22  48250.0
# 3    David   24  48000.0
# 4     Emma   26  55000.0
#
# ===== FILTERING =====
#       Name  Age   Salary
# 1      Bob   25  50000.0
# 2  Charlie   22  48250.0
# 3    David   24  48000.0
# 4     Emma   26  55000.0
#
# ===== SORTING =====
#       Name  Age   Salary
# 4     Emma   26  55000.0
# 1      Bob   25  50000.0
# 2  Charlie   22  48250.0
# 3    David   24  48000.0
# 0    Alice   23  40000.0
#
# ===== GROUPING AND AGGREGATION =====
# Department
# ...
