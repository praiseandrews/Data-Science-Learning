# %% [markdown]
# <a href="https://colab.research.google.com/github/praiseandrews/Data-Science-Learning/blob/main/02_NumPy_Practice/numpy_arrays.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

arr = np.array([1, 2, 3, 4, 5])

print("NumPy Array:")
print(arr)

print("Shape:", arr.shape)
print("Dimensions:", arr.ndim)
# Out:
# NumPy Array:
# [1 2 3 4 5]
# Shape: (5,)
# Dimensions: 1
